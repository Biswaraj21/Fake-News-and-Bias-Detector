# %%
import pandas as pd
df=pd.read_csv("C:/Users/91891/Desktop/Projects/Fake-News-and-Bias-Detector/data/processed/news_dataset.csv")
print(df["label"].value_counts())
# Out:
# label
# 1    23481
# 0    21417
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      1
# 1  House Intelligence Committee Chairman Devin Nu...      1
# 2  On Friday, it was revealed that former Milwauk...      1
# 3  On Christmas day, Donald Trump announced that ...      1
# 4  Pope Francis used his annual Christmas Day mes...      1

# %%
import pandas as pd

df = pd.read_csv("C:/Users/91891/Desktop/Projects/Fake-News-and-Bias-Detector/data/processed/clean_news_dataset.csv")

print(df.isnull().sum())
# Out:
# text     715
# label      0
# dtype: int64

# %%
df=df.dropna()
print(df.isnull().sum())
# Out:
# text     0
# label    0
# dtype: int64
